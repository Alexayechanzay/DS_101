# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

print(pd.__version__)
# Out:
# 3.0.3

# %%
data = pd.read_csv("clean_movieData.csv")
data
# Out:
#       prod_budget       gross
# 0         1000000          26
# 1           10000         401
# 2          400000         423
# 3          750000         450
# 4           10000         527
# ...           ...         ...
# 5029    225000000  1519479547
# 5030    215000000  1671640593
# 5031    306000000  2058662225
# 5032    200000000  2207615668
# 5033    425000000  2783918982
#
# [5034 rows x 2 columns]

# %%
X = DataFrame(data, columns=["prod_budget"])
Y = DataFrame(data, columns=["gross"])

# %%
plt.scatter(X,Y, alpha=0.5)

# labellling
plt.title("Movie Production Budget and Gross")
plt.xlabel("Production Budget (Million)")
plt.ylabel("Gross (Billion)")

# limit x and y intervals 
plt.ylim(0,3000000000) 
plt.xlim(0,450000000)

regression = LinearRegression()
regression.fit(X,Y) # best of line fit
plt.plot(X,regression.predict(X), color="red", linewidth=3)

print("weight m", regression.coef_)
print("intercept b", regression.intercept_)
print("C_coef r",regression.score(X,Y))

plt.show()
# Out:
# weight m [[3.11150918]]
# intercept b [-7236192.7291396]
# C_coef r 0.5496485356985729
